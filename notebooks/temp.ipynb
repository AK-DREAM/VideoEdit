# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
from pathlib import Path
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
if parent_dir not in sys.path:
    sys.path.append(parent_dir)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.agent.llm_interface import chat_with_llm, Message

# %%
chat_with_llm(
    [
        Message(role="user")
        .add_video("file:///home/keli/VideoEdit/notebooks/tmp.mp4")
        .add_text("这段视频的内容是什么?")
        .to_dict()
    ]
)
# Out:
# '\n\n这段视频呈现了**超级英雄题材的动作电影片段**，核心围绕一位装备高科技装置的主角展开，结合了惊险动作、城市追逐与高危场景，以下是关键内容梳理：  \n\n### 1. **角色与装备**  \n- 主角（疑似蜘蛛侠系列角色）佩戴**发光科技手套**（蓝色光效、机械结构），暗示其拥有特殊能力或装备。  \n- 高潮场景中出现“**CHARGING 9 SECONDS**”（充电9秒）的倒计时提示，表明装备需充电后才能启动关键能力（如喷射器、攀爬装置等）。  \n\n### 2. **核心动作场景**  \n- **高空冒险**：角色从高楼边缘跃下（玻璃幕墙外）、在悬崖/建筑外侧攀爬，展现超凡体能。  \n- **城市追逐**：摩托疾驰于山路、街道追车、在狭窄巷道或摩天大楼间穿梭，动作戏密集。  \n- **激烈对抗**：手持武器（刀、棍）与敌人搏斗，多人围攻、近身打斗；画面包含爆炸、碎片飞溅等特效，营造紧张感。  \n- **水下/特殊环境**：角色跌入水中、在金属管道/废墟中穿行，场景多样且充满压迫感。  \n\n### 3. **标志性元素**  \n- **城市地标**：悉尼港大桥、高楼集群等场景，暗示故事发生在澳大利亚或国际化都市。  \n- **科幻细节**：发光手套、机械装置、充电提示，强化“科技赋能”的超级英雄设定。  \n- **紧张节奏**：从暗色走廊到爆炸、跳楼、摩托飞驰，画面切换快速，突出动作电影的爽快感。  \n\n### 4. **风格与指向**  \n- 画面风格偏**写实动作片**（非动画），结合好莱坞特技摄影（如慢镜头、动态跟踪），符合《蜘蛛侠：英雄无归》或《蜘蛛侠：纵横宇宙》（注：后者为动画，此片段更偏向真人版）的同类叙事逻辑。  \n- 整体节奏紧凑，通过“装备限制（充电倒计时）”“高危场景（跳楼、爆炸）”制造悬念，属于经典英雄片“冒险-危机-反击”的叙事模式。  \n\n**总结**：视频浓缩了超级英雄的冒险史诗——主角在科技辅助下，于城市丛林中突破极限、对抗危机，以高燃动作与科幻设定传递“英雄的日常就是危机四伏”的主题。'
