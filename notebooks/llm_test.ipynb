# %%
import os
import sys
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

# %%
from src.agent.llm_interface import chat_with_llm

# %%
chat_with_llm(
    [
        {
            "role": "user",
            "content": "9.9和9.11哪个更大，只输出更大的那个"
        },
    ],
)
# Out:
# '9.11'
