# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
import torchvision.transforms.functional as F


plt.rcParams["savefig.bbox"] = "tight"


def plot(imgs, **imshow_kwargs):
    if not isinstance(imgs[0], list):
        # Make a 2d grid even if there's just 1 row
        imgs = [imgs]

    num_rows = len(imgs)
    num_cols = len(imgs[0])
    _, axs = plt.subplots(nrows=num_rows, ncols=num_cols, squeeze=False)
    for row_idx, row in enumerate(imgs):
        for col_idx, img in enumerate(row):
            ax = axs[row_idx, col_idx]
            img = F.to_pil_image(img.to("cpu"))
            ax.imshow(np.asarray(img), **imshow_kwargs)
            ax.set(xticklabels=[], yticklabels=[], xticks=[], yticks=[])

    plt.tight_layout()

# %%
from pathlib import Path

video_path = Path("/home/keli/VideoEdit/test/basketball.mp4")

# %%
video_path.exists()
# Out:
# False

# %%
len(frames)
# Out:
# 0

# %%
from torchvision.io import read_video
frames, _, _ = read_video(str(video_path), output_format="TCHW")

img1_batch = torch.stack([frames[100], frames[150]])
img2_batch = torch.stack([frames[101], frames[151]])

plot(img1_batch)
# Out:
# /home/keli/VideoEdit/.venv/lib/python3.12/site-packages/torchvision/io/_video_deprecation_warning.py:9: UserWarning: The video decoding and encoding capabilities of torchvision are deprecated from version 0.22 and will be removed in version 0.24. We recommend that you migrate to TorchCodec, where we'll consolidate the future decoding/encoding capabilities of PyTorch: https://github.com/pytorch/torchcodec
#   warnings.warn(
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 4
#       1 from torchvision.io import read_video
#       2 frames, _, _ = read_video(str(video_path), output_format="TCHW")
# ----> 4 img1_batch = torch.stack([frames[100], frames[150]])
#       5 img2_batch = torch.stack([frames[101], frames[151]])
#       7 plot(img1_batch)
#
# IndexError: index 100 is out of bounds for dimension 0 with size 0

# %%
from torchvision.models.optical_flow import Raft_Large_Weights

weights = Raft_Large_Weights.DEFAULT
transforms = weights.transforms()


def preprocess(img1_batch, img2_batch):
    img1_batch = F.resize(img1_batch, size=[520, 960], antialias=False)
    img2_batch = F.resize(img2_batch, size=[520, 960], antialias=False)
    return transforms(img1_batch, img2_batch)


img1_batch, img2_batch = preprocess(img1_batch, img2_batch)

print(f"shape = {img1_batch.shape}, dtype = {img1_batch.dtype}")
# Out:
# shape = torch.Size([2, 3, 520, 960]), dtype = torch.float32

# %%
from torchvision.models.optical_flow import raft_large

# If you can, run this example on a GPU, it will be a lot faster.
device = "cuda" if torch.cuda.is_available() else "cpu"

model = raft_large(weights=Raft_Large_Weights.DEFAULT, progress=False).to(device)
model = model.eval()

list_of_flows = model(img1_batch.to(device), img2_batch.to(device))
print(f"type = {type(list_of_flows)}")
print(f"length = {len(list_of_flows)} = number of iterations of the model")
# Out:
# type = <class 'list'>
# length = 12 = number of iterations of the model

# %%
predicted_flows = list_of_flows[-1]
print(f"dtype = {predicted_flows.dtype}")
print(f"shape = {predicted_flows.shape} = (N, 2, H, W)")
print(f"min = {predicted_flows.min()}, max = {predicted_flows.max()}")
# Out:
# dtype = torch.float32
# shape = torch.Size([2, 2, 520, 960]) = (N, 2, H, W)
# min = -3.899899959564209, max = 6.401098728179932

# %%
from torchvision.utils import flow_to_image

flow_imgs = flow_to_image(predicted_flows)

# The images have been mapped into [-1, 1] but for plotting we want them in [0, 1]
img1_batch = [(img1 + 1) / 2 for img1 in img1_batch]

grid = [[img1, flow_img] for (img1, flow_img) in zip(img1_batch, flow_imgs)]
plot(grid)

# %%
from torchvision.io import write_jpeg
for i, (img1, img2) in enumerate(zip(frames, frames[1:])):
    # Note: it would be faster to predict batches of flows instead of individual flows
    img1, img2 = preprocess(img1, img2)

    list_of_flows = model(img1.unsqueeze(0).to(device), img2.unsqueeze(0).to(device))
    predicted_flow = list_of_flows[-1][0]
    flow_img = flow_to_image(predicted_flow).to("cpu")
    output_folder = "/tmp/"  # Update this to the folder of your choice
    write_jpeg(flow_img, output_folder + f"predicted_flow_{i}.jpg")

# %%
! ffmpeg -f image2 -framerate 30 -i /tmp/predicted_flow_%d.jpg -loop -1 flow.gif
# Out:
# ffmpeg version 7.0.2-static https://johnvansickle.com/ffmpeg/  Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 8 (Debian 8.3.0-6)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-debug --disable-ffplay --disable-indev=sndio --disable-outdev=sndio --cc=gcc --enable-fontconfig --enable-frei0r --enable-gnutls --enable-gmp --enable-libgme --enable-gray --enable-libaom --enable-libfribidi --enable-libass --enable-libvmaf --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librubberband --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libvorbis --enable-libopus --enable-libtheora --enable-libvidstab --enable-libvo-amrwbenc --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libdav1d --enable-libxvid --enable-libzvbi --enable-libzimg
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, image2, from '/tmp/predicted_flow_%d.jpg':
#   Duration: 00:00:11.07, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 960x520 [SAR 1:1 DAR 24:13], 30 fps, 30 tbr, 30 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> gif (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x78ac28014f40] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x78ac28014f40] [swscaler @ 0x78ac280236c0] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28014f40] [swscaler @ 0x78ac28032ec0] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28014f40] [swscaler @ 0x78ac280426c0] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28014f40] [swscaler @ 0x78ac28051ec0] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28014f40] [swscaler @ 0x78ac280616c0] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28014f40] [swscaler @ 0x78ac28070ec0] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28014f40] [swscaler @ 0x78ac280806c0] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28014f40] [swscaler @ 0x78ac2808fec0] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28014f40] [swscaler @ 0x78ac2809f6c0] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28014f40] [swscaler @ 0x78ac280aeec0] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28014f40] [swscaler @ 0x78ac280be6c0] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28014f40] [swscaler @ 0x78ac280cdec0] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28014f40] [swscaler @ 0x78ac280dd6c0] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28014f40] [swscaler @ 0x78ac280ecec0] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28014f40] [swscaler @ 0x78ac280fc6c0] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28014f40] [swscaler @ 0x78ac2810bec0] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac280236c0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x78ac280236c0] [swscaler @ 0x78ac28030680] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac280236c0] [swscaler @ 0x78ac2803d640] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac280236c0] [swscaler @ 0x78ac2804a600] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac280236c0] [swscaler @ 0x78ac280575c0] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac280236c0] [swscaler @ 0x78ac28064580] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac280236c0] [swscaler @ 0x78ac28072540] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac280236c0] [swscaler @ 0x78ac28081d40] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac280236c0] [swscaler @ 0x78ac28091540] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac280236c0] [swscaler @ 0x78ac280a0d40] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac280236c0] [swscaler @ 0x78ac280b0540] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac280236c0] [swscaler @ 0x78ac280bfd40] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac280236c0] [swscaler @ 0x78ac280cf540] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac280236c0] [swscaler @ 0x78ac280ded40] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac280236c0] [swscaler @ 0x78ac280ee540] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac280236c0] [swscaler @ 0x78ac280fdd40] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac280236c0] [swscaler @ 0x78ac2810d540] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28023180] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x78ac28023180] [swscaler @ 0x78ac28030140] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28023180] [swscaler @ 0x78ac2803d100] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28023180] [swscaler @ 0x78ac2804a0c0] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28023180] [swscaler @ 0x78ac28057080] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28023180] [swscaler @ 0x78ac28064040] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28023180] [swscaler @ 0x78ac28072840] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28023180] [swscaler @ 0x78ac28082040] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28023180] [swscaler @ 0x78ac28091840] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28023180] [swscaler @ 0x78ac280a1040] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28023180] [swscaler @ 0x78ac280b0840] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28023180] [swscaler @ 0x78ac280c0040] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28023180] [swscaler @ 0x78ac280cf840] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28023180] [swscaler @ 0x78ac280df040] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28023180] [swscaler @ 0x78ac280ee840] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28023180] [swscaler @ 0x78ac280fe040] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28023180] [swscaler @ 0x78ac2810d840] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28023180] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x78ac28023180] [swscaler @ 0x78ac28030140] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28023180] [swscaler @ 0x78ac2803d100] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28023180] [swscaler @ 0x78ac2804a0c0] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28023180] [swscaler @ 0x78ac28057080] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28023180] [swscaler @ 0x78ac28064040] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28023180] [swscaler @ 0x78ac28073840] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28023180] [swscaler @ 0x78ac28083040] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28023180] [swscaler @ 0x78ac28092840] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28023180] [swscaler @ 0x78ac280a2040] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28023180] [swscaler @ 0x78ac280b1840] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28023180] [swscaler @ 0x78ac280c1040] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28023180] [swscaler @ 0x78ac280d0840] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28023180] [swscaler @ 0x78ac280e0040] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28023180] [swscaler @ 0x78ac280ef840] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28023180] [swscaler @ 0x78ac280ff040] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x78ac28023180] [swscaler @ 0x78ac2811bbc0] No accelerated colorspace conversion found from yuv420p to bgr8.
# Output #0, gif, to 'flow.gif':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Stream #0:0: Video: gif, bgr8(pc, gbr/unknown/unknown, progressive), 960x520 [SAR 1:1 DAR 24:13], q=2-31, 200 kb/s, 30 fps, 100 tbn
#       Metadata:
#         encoder         : Lavc61.3.100 gif
# [out#0/gif @ 0x9bf7580] video:18935KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.000005%
# frame=  332 fps=169 q=-0.0 Lsize=   18935KiB time=00:00:11.06 bitrate=14016.8kbits/s speed=5.63x
